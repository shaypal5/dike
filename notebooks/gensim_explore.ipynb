# %%
from gensim.models import Word2Vec

# %%
import gensim.downloader as api

# %%
print(api.load("glove-twitter-25", return_path=True))  # output: /home/user/gensim-data/glove-twitter-25/glove-twitter-25.gz
# Out:
# /Users/shaypalachy/gensim-data/glove-twitter-25/glove-twitter-25.gz

# %%
model = api.load("glove-twitter-25")  # download the model and return as object ready for use

# %%
api.load?

# %%
model

# %%
model.__dict__.keys()
# Out:
# dict_keys(['vectors', 'vocab', 'vector_size', 'index2word', 'vectors_norm'])

# %%
len(model.vocab)
# Out:
# 1193514

# %%
model.vocab['the'].__dict__
# Out:
# {'count': 1193501, 'index': 13}

# %%
model.vocab['me'].__dict__
# Out:
# {'count': 1193493, 'index': 21}

# %%
model.vocab['people'].__dict__
# Out:
# {'count': 1193384, 'index': 130}

# %%
model.vocab['encyclopedia'].__dict__
# Out:
# {'count': 1091765, 'index': 101749}

# %%
1091765 + 101749
# Out:
# 1193514

# %%
model.vocab
# Out:
# {'<user>': <gensim.models.keyedvectors.Vocab at 0x119da3630>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x119da3b00>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x119da36d8>,
#  'rt': <gensim.models.keyedvectors.Vocab at 0x119da3278>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x119da3710>,
#  '<repeat>': <gensim.models.keyedvectors.Vocab at 0x119da3940>,
#  '<hashtag>': <gensim.models.keyedvectors.Vocab at 0x119da3898>,
#  '<number>': <gensim.models.keyedvectors.Vocab at 0x119da34a8>,
#  '<url>': <gensim.models.keyedvectors.Vocab at 0x119da3978>,
#  '!': <gensim.models.keyedvectors.Vocab at 0x119da3518>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x119da39b0>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x119da3550>,
#  '"': <gensim.models.keyedvectors.Vocab at 0x119da39e8>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x119da3438>,
#  '?': <gensim.models.keyedvectors.Vocab at 0x119da3a90>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x119da33c8>,
# ...

# %%
with open('/Users/shaypalachy/data/)
for word in model.vocab:
